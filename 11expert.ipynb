# %%
print("Name: Aditya Kokate")
print("Roll no.: TACO22147")
# Out:
# Name: Aditya Kokate
# Roll no.: TACO22147

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/gsr/Documents/Extended_Employee_Performance_and_Productivity_Data.csv')

print(df.head())
# Out:
#    Employee_ID        Department  Gender  Age   Job_Title  \
# 0            1                IT    Male   55  Specialist
# 1            2           Finance    Male   29   Developer
# 2            3           Finance    Male   55  Specialist
# 3            4  Customer Support  Female   48     Analyst
# 4            5       Engineering  Female   36     Analyst
#
#                     Hire_Date  Years_At_Company Education_Level  \
# 0  2022-01-19 08:03:05.556036                 2     High School
# 1  2024-04-18 08:03:05.556036                 0     High School
# 2  2015-10-26 08:03:05.556036                 8     High School
# 3  2016-10-22 08:03:05.556036                 7        Bachelor
# 4  2021-07-23 08:03:05.556036                 3        Bachelor
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0                  5          6750.0                   33                32
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Employee_ID        Department  Gender  Age   Job_Title  \
# 0                1                IT    Male   55  Specialist
# 1                2           Finance    Male   29   Developer
# 2                3           Finance    Male   55  Specialist
# 3                4  Customer Support  Female   48     Analyst
# 4                5       Engineering  Female   36     Analyst
# ...            ...               ...     ...  ...         ...
# 99995        99996           Finance    Male   27  Technician
# 99996        99997                IT  Female   36  Consultant
# 99997        99998        Operations    Male   53     Analyst
# 99998        99999                HR  Female   22  Consultant
# 99999       100000           Finance  Female   43     Analyst
#
#                         Hire_Date  Years_At_Company Education_Level  \
# 0      2022-01-19 08:03:05.556036                 2     High School
# ...

# %%
df.drop(["Department", "Gender",
"Job_Title","Hire_Date","Resigned"],axis=1, inplace=True)

# %%
df.head()
# Out:
#    Employee_ID  Age  Years_At_Company Education_Level  Performance_Score  \
# 0            1   55                 2     High School                  5
# 1            2   29                 0     High School                  5
# 2            3   55                 8     High School                  3
# 3            4   48                 7        Bachelor                  2
# 4            5   36                 3        Bachelor                  2
#
#    Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0          6750.0                   33                32              22
# 1          7500.0                   34                34              13
# 2          5850.0                   37                27               6
# 3          4800.0                   52                10              28
# 4          4800.0                   38                11              29
#
#    Sick_Days  Remote_Work_Frequency  Team_Size  Training_Hours  Promotions  \
# ...

# %%
df["Education_Level"].unique()
# Out:
# array(['High School', 'Bachelor', 'Master', 'PhD'], dtype=object)

# %%
le = LabelEncoder()

# %%
df['Education_Level'] = le.fit_transform(df['Education_Level'])

# %%
df.head()
# Out:
#    Employee_ID  Age  Years_At_Company  Education_Level  Performance_Score  \
# 0            1   55                 2                1                  5
# 1            2   29                 0                1                  5
# 2            3   55                 8                1                  3
# 3            4   48                 7                0                  2
# 4            5   36                 3                0                  2
#
#    Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# 0          6750.0                   33                32              22
# 1          7500.0                   34                34              13
# 2          5850.0                   37                27               6
# 3          4800.0                   52                10              28
# 4          4800.0                   38                11              29
#
#    Sick_Days  Remote_Work_Frequency  Team_Size  Training_Hours  Promotions  \
# ...

# %%
df['High_Performer'] = (df['Performance_Score'] >= 4).astype(int)
df
# Out:
#        Employee_ID  Age  Years_At_Company  Education_Level  Performance_Score  \
# 0                1   55                 2                1                  5
# 1                2   29                 0                1                  5
# 2                3   55                 8                1                  3
# 3                4   48                 7                0                  2
# 4                5   36                 3                0                  2
# ...            ...  ...               ...              ...                ...
# 99995        99996   27                 1                0                  4
# 99996        99997   36                 6                2                  5
# 99997        99998   53                 8                1                  2
# 99998        99999   22                 9                1                  5
# 99999       100000   43                 0                3                  1
#
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='High_Performer', y='Monthly_Salary', data=df,
palette='Set2')
plt.title("Monthly Salary vs. High Performers")
plt.xlabel("High Performer (1 = Yes, 0 = No)")
plt.ylabel("Monthly Salary")
plt.show()
# Out:
# /var/folders/w_/gfznx_810sgcxtklmh10ytr80000gn/T/ipykernel_1003/757473126.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='High_Performer', y='Monthly_Salary', data=df,

# %%
X = df[['Performance_Score', 'Education_Level',
'Employee_Satisfaction_Score', 'Promotions']]
Y = df['High_Performer']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
test_size=0.2, random_state=42)
X_test
# Out:
#        Performance_Score  Education_Level  Employee_Satisfaction_Score  \
# 75721                  2                2                         4.59
# 80184                  4                1                         4.83
# 19864                  3                1                         2.23
# 76699                  1                2                         4.88
# 92991                  4                0                         3.68
# ...                  ...              ...                          ...
# 32595                  3                1                         1.57
# 29313                  4                2                         3.88
# 37862                  2                2                         1.49
# 53421                  5                0                         1.92
# 42410                  3                0                         2.41
#
#        Promotions
# 75721           0
# 80184           1
# 19864           0
# 76699           0
# ...

# %%
lr = LogisticRegression()
lr.fit(X_train, Y_train)
LogisticRegression()
y_pred = lr.predict(X_test)
print("Confusion Matrix:\n", confusion_matrix(Y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[12107     0]
#  [    0  7893]]

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test, y_pred)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  1.0

# %%
prediction = lr.predict([[5, 1, 1.72, 2]])
print(prediction)
# Out:
# [1]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction = lr.predict([[2, 0, 1.25, 1]])
print(prediction)
# Out:
# [0]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
https://github.com/Shravan250/LP-2-practicals
